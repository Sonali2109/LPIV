# %%
from tensorflow import keras
from tensorflow.keras import layers

# Step 1: Load dataset
num_words = 10000
(X_train, y_train), (X_test, y_test) = keras.datasets.imdb.load_data(num_words=num_words)

# Step 2: Pad sequences
X_train = keras.preprocessing.sequence.pad_sequences(X_train, maxlen=200)
X_test = keras.preprocessing.sequence.pad_sequences(X_test, maxlen=200)

# Step 3: Model
model = keras.Sequential([
    layers.Embedding(input_dim=num_words, output_dim=128),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')   # Binary output
])

# Step 4: Compile
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Step 5: Train
history = model.fit(X_train, y_train,
                    epochs=5,
                    validation_split=0.2)

# Step 6: Evaluate
loss, acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", acc)
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 49ms/step - accuracy: 0.7946 - loss: 0.4178 - val_accuracy: 0.8680 - val_loss: 0.3094
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 31s 49ms/step - accuracy: 0.9770 - loss: 0.0672 - val_accuracy: 0.8470 - val_loss: 0.4502
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 47ms/step - accuracy: 0.9986 - loss: 0.0067 - val_accuracy: 0.8486 - val_loss: 0.5806
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 30s 48ms/step - accuracy: 1.0000 - loss: 5.0788e-04 - val_accuracy: 0.8538 - val_loss: 0.5995
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 47ms/step - accuracy: 1.0000 - loss: 1.2627e-04 - val_accuracy: 0.8532 - val_loss: 0.6200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8486 - loss: 0.6466
# Test Accuracy: 0.8485999703407288

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# Here are **high-probability viva questions** for your **Classification using Deep Neural Networks practical** (both OCR multiclass + IMDB binary).
# These are exactly the kind of questions examiners love to ask 👇
#
# ---
#
# # 🎯 BASIC QUESTIONS (must know)
#
# ### 1. What is classification?
#
# * Predicting **categorical output** (labels/classes)
#
# ---
#
# ### 2. Difference between classification and regression?
#
# * Classification → discrete output
# * Regression → continuous output
#
# ---
#
# ### 3. Types of classification?
#
# * **Binary classification** (2 classes)
# * **Multiclass classification** (more than 2 classes)
#
# ---
#
# ### 4. Examples from your practical?
#
# * Binary → IMDB (positive/negative)
# * Multiclass → OCR (A–Z letters)
#
# ---
#
# # 🧠 MODEL RELATED QUESTIONS
#
# ### 5. Why use Deep Neural Network?
#
# * To learn **complex patterns** from data
#
# ---
#
# ### 6. What is a Dense layer?
#
# * Fully connected layer
#
# ---
#
# ### 7. What is activation function?
#
# * Introduces **non-linearity** in model
#
# ---
#
# # 🔴 BINARY CLASSIFICATION (IMDB)
#
# ### 8. Why output layer has 1 neuron?
#
# * Only **2 classes (0 or 1)**
#
# ---
#
# ### 9. Why use sigmoid activation?
#
# * Outputs value between **0 and 1 (probability)**
#
# ---
#
# ### 10. What is binary crossentropy?
#
# * Loss function for binary classification
#
# ---
#
# ### 11. How prediction is made?
#
# * If output > 0.5 → class 1
# * Else → class 0
#
# ---
#
# ### 12. What is Embedding layer?
#
# * Converts words into **dense vectors**
#
# ---
#
# ### 13. Why padding is required?
#
# * To make all input sequences **same length**
#
# ---
#
# # 🔵 MULTICLASS CLASSIFICATION (OCR)
#
# ### 14. Why output layer has 26 neurons?
#
# * 26 possible classes (A–Z)
#
# ---
#
# ### 15. Why use softmax activation?
#
# * Converts outputs into **probabilities summing to 1**
#
# ---
#
# ### 16. What is categorical crossentropy?
#
# * Loss function for multiclass classification
#
# ---
#
# ### 17. What is label encoding?
#
# * Converting labels (A–Z) into numbers (0–25)
#
# ---
#
# # ⚙️ TRAINING QUESTIONS
#
# ### 18. What is epoch?
#
# * One complete pass over training data
#
# ---
#
# ### 19. What is batch size?
#
# * Number of samples processed at once
#
# ---
#
# ### 20. What is optimizer?
#
# * Algorithm to update weights (e.g., Adam)
#
# ---
#
# ### 21. What is validation split?
#
# * Portion of training data used for validation
#
# ---
#
# # 📊 PERFORMANCE & PLOTS
#
# ### 22. What is accuracy?
#
# * Percentage of correct predictions
#
# ---
#
# ### 23. Training vs validation accuracy?
#
# * Training → performance on training data
# * Validation → performance on unseen data
#
# ---
#
# ### 24. What is overfitting?
#
# * Good training accuracy but poor validation accuracy
#
# ---
#
# ### 25. How to detect overfitting?
#
# * Validation accuracy decreases while training increases
#
# ---
#
# # 🔥 IMPORTANT DIFFERENCE QUESTIONS
#
# ### 26. Difference between sigmoid and softmax?
#
# | Sigmoid            | Softmax                |
# | ------------------ | ---------------------- |
# | Binary output      | Multiclass output      |
# | Single probability | Multiple probabilities |
# | Range: 0–1         | Sum = 1                |
#
# ---
#
# ### 27. Difference between binary and categorical crossentropy?
#
# | Binary            | Categorical       |
# | ----------------- | ----------------- |
# | 2 classes         | Multiple classes  |
# | Used with sigmoid | Used with softmax |
#
# ---
#
# # ⚡ ADVANCED QUESTIONS (to impress)
#
# ### 28. What is vanishing gradient problem?
#
# * Gradients become very small → slow learning
#
# ---
#
# ### 29. Why use ReLU?
#
# * Faster training
# * Avoids vanishing gradient
#
# ---
#
# ### 30. What is generalization?
#
# * Model performs well on unseen data
#
# ---
#
# ### 31. How to improve accuracy?
#
# * More data
# * Better model
# * Hyperparameter tuning
#
# ---
#
# # 🎯 READY-MADE VIVA ANSWER (say this confidently)
#
# 👉 *“Binary classification uses sigmoid activation with one output neuron, while multiclass classification uses softmax with multiple neurons. Loss functions differ accordingly, and accuracy is used to evaluate performance.”*
#
# ---
#
# # 🧠 1-MINUTE REVISION
#
# 👉 Binary → sigmoid + 1 neuron
# 👉 Multiclass → softmax + many neurons
# 👉 Loss → binary vs categorical
# 👉 Accuracy → performance metric

# %% [markdown]
# **OUTPUT :**
#
# Great — this is a **very typical IMDB DNN output**, and examiners *love* asking this. Let’s decode it in a **simple + viva-ready way** 👇
#
# ---
#
# # 📊 1. WHAT EACH LINE MEANS
#
# Example:
#
# ```
# accuracy: 0.7946 - loss: 0.4178
# val_accuracy: 0.8680 - val_loss: 0.3094
# ```
#
# ### ✅ Terms:
#
# * **accuracy** → training accuracy
# * **loss** → training error
# * **val_accuracy** → validation accuracy
# * **val_loss** → validation error
#
# ---
#
# # 📈 2. TRAINING PERFORMANCE
#
# ### From your output:
#
# | Epoch | Train Accuracy | Train Loss |
# | ----- | -------------- | ---------- |
# | 1     | 79%            | 0.41       |
# | 2     | 97%            | 0.06       |
# | 3     | 99.8%          | 0.006      |
# | 4     | 100%           | ~0         |
# | 5     | 100%           | ~0         |
#
# ### ✅ Meaning:
#
# 👉 Model is learning **very fast**
# 👉 By Epoch 4–5 → almost **perfect training accuracy**
#
# ✔ This looks good BUT…
#
# ---
#
# # ⚠️ 3. VALIDATION PERFORMANCE (IMPORTANT)
#
# | Epoch | Val Accuracy | Val Loss |
# | ----- | ------------ | -------- |
# | 1     | 86%          | 0.30     |
# | 2     | 84%          | 0.45     |
# | 3     | 84%          | 0.58     |
# | 4     | 85%          | 0.59     |
# | 5     | 85%          | 0.62     |
#
# ### 🚨 Key Observation:
#
# 👉 Training accuracy → **increasing to 100%**
# 👉 Validation accuracy → **stuck around 84–85%**
# 👉 Validation loss → **increasing**
#
# ---
#
# # 🔥 4. FINAL CONCLUSION (VERY IMPORTANT)
#
# 👉 This indicates:
#
# ## ❗ OVERFITTING
#
# ### Why?
#
# * Model **memorizes training data**
# * But **fails to generalize** to new data
#
# ---
#
# # 📊 5. TEST RESULT
#
# ```
# Test Accuracy: 0.8486 (~85%)
# ```
#
# ### ✅ Meaning:
#
# 👉 On unseen data → model predicts correctly **~85% of the time**
#
# ✔ This is **decent accuracy**
#
# ---
#
# # 🎯 6. PERFECT VIVA ANSWER (say this)
#
# 👉 *“The model achieves very high training accuracy but validation accuracy remains around 85% and validation loss increases, indicating overfitting. The test accuracy is around 85%, which shows reasonable generalization.”*
#
# ---
#
# # 🧠 7. WHY OVERFITTING HAPPENED?
#
# Because:
#
# * Model is **too powerful**
# * Dataset is **limited**
# * Training too long (epochs)
#
# ---
#
# # ⚡ 8. HOW TO IMPROVE (examiner may ask)
#
# You can say:
#
# * Use **Dropout layer**
# * Reduce epochs
# * Use **EarlyStopping**
# * Simplify model
#
# ---
#
# # 📉 9. SIMPLE VISUAL UNDERSTANDING
#
# 👉 Good model:
#
# * Train accuracy ↑
# * Validation accuracy ↑
#
# 👉 Your model:
#
# * Train accuracy ↑↑↑ (100%)
# * Validation accuracy → flat
#
# ➡️ ❗ Overfitting
#
# ---
#
# # 🧠 10. QUICK MEMORY LINE
#
# 👉 “High training accuracy + stagnant validation accuracy = Overfitting”
